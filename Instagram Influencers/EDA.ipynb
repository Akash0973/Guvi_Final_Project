# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

data=pd.read_csv('C:\Guvi_final_project\Instagram Influencers/Influencer.csv')

# %%
data
# Out:
#      Rank           Channel Info  Influence Score Followers Avg. Likes Posts  \
# 0       1            \ncristiano               92    485.2m       8.7m  3.4k
# 1       2            kyliejenner               91    370.7m       8.2m  7.0k
# 2       3             \nleomessi               90    363.9m       6.7m   915
# 3       4          \nselenagomez               93    348.8m       6.1m  1.9k
# 4       5              \ntherock               91    339.4m       1.8m  6.8k
# ..    ...                    ...              ...       ...        ...   ...
# 195   196  \nkhabib_nurmagomedov               63     33.6m     680.6k  4.6k
# 196   197         \ndanbilzerian               84     33.6m       2.2m  1.4k
# 197   198            \nraisa6690               80     33.6m     227.8k  4.2k
# 198   199          \nluansantana               79     33.5m     193.3k   865
# 199   200           \nnancyajram               81     33.4m     382.5k  3.8k
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 200 non-null    int64
#  1   Channel Info         200 non-null    object
#  2   Influence Score      200 non-null    int64
#  3   Followers            200 non-null    object
#  4   Avg. Likes           200 non-null    object
#  5   Posts                200 non-null    object
#  6   60-Day Eng Rate      200 non-null    float64
#  7   New Post Avg. Likes  200 non-null    object
#  8   Total Likes          200 non-null    object
#  9   Country Or Region    137 non-null    object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 15.8+ KB

# %%
def cleaner(value):
    suf=value[-1]
    num=value[0:-1]
    if suf=='k':
        return (1000*float(num))
    elif suf=='m':
        return (1000000*float(num))
    elif suf=='b':
        return (1000000000*float(num))
    else:
        return float(value)

def name_cleaner(name):
    name=name.replace('\n','')
    return name

# %%
data['Followers']=data['Followers'].apply(cleaner)
data['Avg. Likes']=data['Avg. Likes'].apply(cleaner)
data['Posts']=data['Posts'].apply(cleaner)
data['New Post Avg. Likes']=data['New Post Avg. Likes'].apply(cleaner)
data['Total Likes']=data['Total Likes'].apply(cleaner)
data['Channel Info']=data['Channel Info'].apply(name_cleaner)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rank                 200 non-null    int64
#  1   Channel Info         200 non-null    object
#  2   Influence Score      200 non-null    int64
#  3   Followers            200 non-null    float64
#  4   Avg. Likes           200 non-null    float64
#  5   Posts                200 non-null    float64
#  6   60-Day Eng Rate      200 non-null    float64
#  7   New Post Avg. Likes  200 non-null    float64
#  8   Total Likes          200 non-null    float64
#  9   Country Or Region    137 non-null    object
# dtypes: float64(6), int64(2), object(2)
# memory usage: 15.8+ KB

# %%
data.head()
# Out:
#    Rank Channel Info  Influence Score    Followers  Avg. Likes   Posts  \
# 0     1    cristiano               92  485200000.0   8700000.0  3400.0
# 1     2  kyliejenner               91  370700000.0   8200000.0  7000.0
# 2     3     leomessi               90  363900000.0   6700000.0   915.0
# 3     4  selenagomez               93  348800000.0   6100000.0  1900.0
# 4     5      therock               91  339400000.0   1800000.0  6800.0
#
#    60-Day Eng Rate  New Post Avg. Likes   Total Likes Country Or Region
# 0            0.013            6300000.0  2.910000e+10             Spain
# 1            0.014            5000000.0  5.740000e+10     United States
# 2            0.010            3500000.0  6.100000e+09               NaN
# 3            0.005            1700000.0  1.140000e+10     United States
# 4            0.003             932000.0  1.260000e+10     United States

# %%
data['Country Or Region'].value_counts()
# Out:
# United States             65
# Brazil                    13
# India                     12
# Indonesia                  7
# France                     6
# Spain                      5
# United Kingdom             4
# Colombia                   3
# Canada                     3
# Mexico                     2
# Turkey                     2
# Netherlands                2
# Switzerland                1
# Germany                    1
# Czech Republic             1
# British Virgin Islands     1
# Sweden                     1
# Australia                  1
# Anguilla                   1
# C̫te d'Ivoire             1
# Puerto Rico                1
# United Arab Emirates       1
# Italy                      1
# Uruguay                    1
# Russia                     1
# Name: Country Or Region, dtype: int64

# %%
filtered_data=data.drop(['Channel Info','Country Or Region'],axis=1)
filtered_data
# Out:
#      Rank  Influence Score    Followers  Avg. Likes   Posts  60-Day Eng Rate  \
# 0       1               92  485200000.0   8700000.0  3400.0            0.013
# 1       2               91  370700000.0   8200000.0  7000.0            0.014
# 2       3               90  363900000.0   6700000.0   915.0            0.010
# 3       4               93  348800000.0   6100000.0  1900.0            0.005
# 4       5               91  339400000.0   1800000.0  6800.0            0.003
# ..    ...              ...          ...         ...     ...              ...
# 195   196               63   33600000.0    680600.0  4600.0            0.009
# 196   197               84   33600000.0   2200000.0  1400.0            0.064
# 197   198               80   33600000.0    227800.0  4200.0            0.003
# 198   199               79   33500000.0    193300.0   865.0            0.003
# 199   200               81   33400000.0    382500.0  3800.0            0.004
#
#      New Post Avg. Likes   Total Likes
# ...

# %%
sns.heatmap(filtered_data.corr(), annot=True, cmap='YlGnBu', cbar=True)
plt.show()

# %% [markdown]
# Ans1-
#
# Correlated features-
# 1) Rank vs Followers: -0.7
# 2) 60-Day Eng Rate vs Avg. Likes: 0.79
# 3) New Post Avg. Likes vs Avg. Likes: 0.89
# 4) New Post Avg. Likes vs 60-Day Eng Rate: 0.87
# 5) Total Likes vs Followers: 0.67
# 6) Total Likes vs Rank: -0.47

# %%
plt.hist(data['Influence Score'],bins=50)
plt.show()

# %%
plt.hist(data['Avg. Likes'],bins=50)
plt.show()

# %%
plt.hist(data['Posts'],bins=50)
plt.show()

# %% [markdown]
# Ans 2-
#
# Influence score is Negatively skewed Normally Distributed
#
# Average likes and posts are Exponentially Distributed

# %%
country=data['Country Or Region'].value_counts().reset_index()
country
# Out:
#                      index  Country Or Region
# 0            United States                 65
# 1                   Brazil                 13
# 2                    India                 12
# 3                Indonesia                  7
# 4                   France                  6
# 5                    Spain                  5
# 6           United Kingdom                  4
# 7                 Colombia                  3
# 8                   Canada                  3
# 9                   Mexico                  2
# 10                  Turkey                  2
# 11             Netherlands                  2
# 12             Switzerland                  1
# 13                 Germany                  1
# 14          Czech Republic                  1
# 15  British Virgin Islands                  1
# 16                  Sweden                  1
# 17               Australia                  1
# 18                Anguilla                  1
# ...

# %%
sns.barplot(x=country['index'],y=country['Country Or Region'])
plt.xticks(rotation='vertical')
plt.ylabel('Number of Influencers')
plt.xlabel('Countries')
plt.show()

# %% [markdown]
# Ans3-
#
# Country wise number of influencers distribution

# %%
top10_by_Followers=data.sort_values(by='Followers',ascending=False).head(10)['Channel Info'].reset_index(drop=True)
top10_by_Avg_Likes=data.sort_values(by='Avg. Likes',ascending=False).head(10)['Channel Info'].reset_index(drop=True)
top10_by_Tot_Likes=data.sort_values(by='Total Likes',ascending=False).head(10)['Channel Info'].reset_index(drop=True)

# %%
top_10=pd.concat([top10_by_Followers,top10_by_Avg_Likes,top10_by_Tot_Likes],axis=1)
top_10.columns=['Followers','Average Likes','Total Likes']
top_10
# Out:
#          Followers Average Likes    Total Likes
# 0        cristiano           thv    kyliejenner
# 1      kyliejenner           j.m      cristiano
# 2         leomessi         rkive        zendaya
# 3      selenagomez     cristiano  kimkardashian
# 4          therock  billieeilish   arianagrande
# 5     arianagrande   kyliejenner     badgalriri
# 6    kimkardashian      leomessi       neymarjr
# 7          beyonce   selenagomez   justinbieber
# 8  khloekardashian  lalalalisa_m     nickiminaj
# 9     justinbieber       zendaya        therock

# %% [markdown]
# Ans4-
#
# Top 10 influencers

# %%
plt.scatter(data['Followers'],data['Total Likes'])
plt.show()

# %%
plt.scatter(data['Followers'],data['Influence Score'])
plt.show()

# %%
plt.scatter(data['Posts'],data['Avg. Likes'])
plt.show()

# %%
plt.scatter(data['Posts'],data['Influence Score'])
plt.show()

# %% [markdown]
# Ans 5-
#
# 1) Followers vs Total Likes: Linear
# 2) Followers vs Influence Score: Log
# 3) Posts vs Average Likes: Exponential
# 4) Posts vs Influence Score: No relationore
